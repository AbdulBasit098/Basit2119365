# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df1=pd.read_csv(r"D:\w\fashion dataset.csv")
df1
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14324  17029604.0  The Chennai Silks Pink & Silver-Toned Floral Z...  3999.0
# 14325  17600212.0  Kinder Kids Girls Blue & Green Printed Foil Pr...  2050.0
# 14326  18159266.0  KLOTTHE Women Green & Black Floral Printed Pal...  1659.0
# 14327  18921114.0             InWeave Women Red Printed A-Line Skirt  2399.0
# 14328  19361058.0      BoStreet Women Navy Blue Tapered Fit Trousers  2599.0
#
# ...

# %%
df2=pd.read_excel(r"D:\w\fashion brand details.xlsx")
df2
# Out:
#       brand_id    brand_name
# 0            1           513
# 1            2          109F
# 2            3     20Dresses
# 3            4   250 Designs
# 4            5          3Pin
# ...        ...           ...
# 1015      1016  Ziva Fashion
# 1016      1017        Zivame
# 1017      1018         Ziyaa
# 1018      1019        Zoella
# 1019      1020          Zola
#
# [1020 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14329 entries, 0 to 14328
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   p_id          14311 non-null  float64
#  1   name          14310 non-null  object
#  2   price         14310 non-null  float64
#  3   colour        14307 non-null  object
#  4   brand_name    14305 non-null  object
#  5   ratingCount   6581 non-null   float64
#  6   avg_rating    6581 non-null   float64
#  7   description   14310 non-null  object
#  8   p_attributes  14310 non-null  object
# dtypes: float64(4), object(5)
# memory usage: 1007.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   brand_id    1020 non-null   int64
#  1   brand_name  1020 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 16.1+ KB

# %%
new_df2 = df2.dropna()
new_df2
# Out:
#       brand_id    brand_name
# 0            1           513
# 1            2          109F
# 2            3     20Dresses
# 3            4   250 Designs
# 4            5          3Pin
# ...        ...           ...
# 1015      1016  Ziva Fashion
# 1016      1017        Zivame
# 1017      1018         Ziyaa
# 1018      1019        Zoella
# 1019      1020          Zola
#
# [1020 rows x 2 columns]

# %%
new_df1 = df1.dropna()
new_df1
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14309  14173362.0  STREET 9 Black Puff Sleeves Blouson Crop Pleat...  1999.0
# 14312  17122946.0  Moda Rapido Women Blue Straight Fit High-Rise ...  2299.0
# 14320  14235030.0  Indo Era Women Black Floral Printed Pure Cotto...  3499.0
# 14322  16835446.0      Allen Solly Woman Women Blue Skinny Fit Jeans  1999.0
# 14323  16944668.0   Berrylush Women Pretty Pink Romantic Florals Top  1799.0
#
# ...

# %%
new_df1.dropna(inplace= True)
# Out:
# C:\Users\iBRAHIM\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
new_df2 = df2.dropna()
new_df2
# Out:
#       brand_id    brand_name
# 0            1           513
# 1            2          109F
# 2            3     20Dresses
# 3            4   250 Designs
# 4            5          3Pin
# ...        ...           ...
# 1015      1016  Ziva Fashion
# 1016      1017        Zivame
# 1017      1018         Ziyaa
# 1018      1019        Zoella
# 1019      1020          Zola
#
# [1020 rows x 2 columns]

# %%
new_df1=new_df1.drop(['description', 'p_attributes'], axis=1)
new_df1
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14309  14173362.0  STREET 9 Black Puff Sleeves Blouson Crop Pleat...  1999.0
# 14312  17122946.0  Moda Rapido Women Blue Straight Fit High-Rise ...  2299.0
# 14320  14235030.0  Indo Era Women Black Floral Printed Pure Cotto...  3499.0
# 14322  16835446.0      Allen Solly Woman Women Blue Skinny Fit Jeans  1999.0
# 14323  16944668.0   Berrylush Women Pretty Pink Romantic Florals Top  1799.0
#
# ...

# %%
print(new_df1.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14309    False
# 14312    False
# 14320    False
# 14322    False
# 14323    False
# Length: 6578, dtype: bool

# %%
print(new_df2.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1015    False
# 1016    False
# 1017    False
# 1018    False
# 1019    False
# Length: 1020, dtype: bool

# %%
print(new_df1.drop_duplicates(inplace = True))
# Out:
# None

# %%
print(new_df2.dropna(inplace = True))
# Out:
# None

# %%
new_df1.corr()
# Out:
#                  p_id     price  ratingCount  avg_rating
# p_id         1.000000  0.136028    -0.214993    0.028580
# price        0.136028  1.000000    -0.048715   -0.051461
# ratingCount -0.214993 -0.048715     1.000000    0.029462
# avg_rating   0.028580 -0.051461     0.029462    1.000000

# %%
new_df2.corr()
# Out:
#           brand_id
# brand_id       1.0

# %%
new_df1
# Out:
#              p_id                                               name   price  \
# 0       1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1       5829334.0  Roadster Women Mustard Yellow Solid Hooded Swe...  1199.0
# 2      10340119.0  Inddus Peach-Coloured & Beige Unstitched Dress...  5799.0
# 3      10856380.0            SASSAFRAS Women Black Parallel Trousers  1499.0
# 4      12384822.0  Kotty Women Black Wide Leg High-Rise Clean Loo...  1999.0
# ...           ...                                                ...     ...
# 14309  14173362.0  STREET 9 Black Puff Sleeves Blouson Crop Pleat...  1999.0
# 14312  17122946.0  Moda Rapido Women Blue Straight Fit High-Rise ...  2299.0
# 14320  14235030.0  Indo Era Women Black Floral Printed Pure Cotto...  3499.0
# 14322  16835446.0      Allen Solly Woman Women Blue Skinny Fit Jeans  1999.0
# 14323  16944668.0   Berrylush Women Pretty Pink Romantic Florals Top  1799.0
#
# ...

# %%
percent_missing = new_df1.isnull().sum() * 100 / len(new_df1)

# %%
print(percent_missing)
# Out:
# p_id           0.0
# name           0.0
# price          0.0
# colour         0.0
# brand_name     0.0
# ratingCount    0.0
# avg_rating     0.0
# dtype: float64

# %%
percent_missing1 = new_df2.isnull().sum() * 100 / len(new_df2)
print(percent_missing1)
# Out:
# brand_id      0.0
# brand_name    0.0
# dtype: float64

# %%
percent_missing.sort_values(ascending=False)
# Out:
# p_id           0.0
# name           0.0
# price          0.0
# colour         0.0
# brand_name     0.0
# ratingCount    0.0
# avg_rating     0.0
# dtype: float64

# %%
percent_missing1.sort_values(ascending=False)
# Out:
# brand_id      0.0
# brand_name    0.0
# dtype: float64

# %%
percent_missing_rows = new_df1.isnull().sum(axis=0) / len(new_df1.columns)
missing_plt = percent_missing_rows.hist()
missing_plt.set_xlabel('Percent missing')
missing_plt.set_ylabel('Number of rows')
# Out:
# Text(0, 0.5, 'Number of rows')

# %%
percent_missing_rows = new_df2.isnull().sum(axis=0) / len(new_df2.columns)
missing_plt = percent_missing_rows.hist()
missing_plt.set_xlabel('Percent missing')
missing_plt.set_ylabel('Number of rows')
# Out:
# Text(0, 0.5, 'Number of rows')

# %%
newdff=pd.merge(new_df1,new_df2, on="brand_name")
newdff
# Out:
#             p_id                                               name   price  \
# 0      1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta   899.0
# 1     10711448.0           Dupatta Bazaar Women White Solid Dupatta   599.0
# 2     14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...   899.0
# 3     13552234.0                 Dupatta Bazaar Black Solid Dupatta   599.0
# 4     12866574.0                Dupatta Bazaar Maroon Solid Dupatta   699.0
# ...          ...                                                ...     ...
# 3933  17647504.0  Roly Poly Women Magenta Ethnic Motifs Embroide...  2663.0
# 3934  18512752.0  Mystere Paris Multicoloured Checked Extended S...   999.0
# 3935  18841584.0        Styli Women Blue High-Rise Heavy Fade Jeans  1949.0
# 3936  18841408.0  Styli Women Blue Super Skinny Fit High-Rise Jeans   799.0
# 3937   2117164.0           Noi Cream-Coloured & Brown Printed Shawl  1999.0
#
# ...

# %%
newdff.dtypes
# Out:
# p_id           float64
# name            object
# price          float64
# colour          object
# brand_name      object
# ratingCount    float64
# avg_rating     float64
# brand_id         int64
# dtype: object

# %%
#Show the highest sales top brand with good rating
newdff.to_csv(r"D:\assign\cleandf.csv")

# %%
y=newdff['ratingCount'].values# response variable or dependent
X=newdff['price'].values
newdff.head()
# Out:
#          p_id                                               name  price  \
# 0   1518329.0   Dupatta Bazaar White Embroidered Chiffon Dupatta  899.0
# 1  10711448.0           Dupatta Bazaar Women White Solid Dupatta  599.0
# 2  14964708.0  Dupatta Bazaar Orange & Green Dyed Art Silk Ba...  899.0
# 3  13552234.0                 Dupatta Bazaar Black Solid Dupatta  599.0
# 4  12866574.0                Dupatta Bazaar Maroon Solid Dupatta  699.0
#
#    colour      brand_name  ratingCount  avg_rating  brand_id
# 0   White  Dupatta Bazaar       1321.0    4.548827       242
# 1   White  Dupatta Bazaar       1531.0    4.536251       242
# 2  Orange  Dupatta Bazaar         30.0    4.366667       242
# 3   Black  Dupatta Bazaar        232.0    4.547414       242
# 4  Maroon  Dupatta Bazaar        118.0    4.245763       242

# %%
X.ndim
# Out:
# 1

# %%
X=X.reshape(-1, 1)
X.shape
# Out:
# (3938, 1)

# %%
X.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
y=y.reshape(-1, 1)
y.shape
# Out:
# (3938, 1)

# %%
y.ndim
# Out:
# 2

# %%
sns.heatmap(newdff.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
mean_x=np.mean(X)
mean_y=np.mean(y)

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([[4.10854135],
#        [4.10901197],
#        [4.10995322],
#        [4.09216363],
#        [4.09959949],
#        [4.07332926],
#        [4.10618823],
#        [4.03106722],
#        [4.08924576],
#        [4.10148199],
#        [4.10712947],
#        [4.01676966],
#        [4.11102624],
#        [4.06383206],
#        [4.07324454],
#        [4.11089447],
#        [4.10901197],
#        [4.10148199],
#        [4.093952  ],
#        [4.10807072],
#        [4.05300771],
#        [4.10807072],
#        [4.08970697],
#        [4.10242323],
#        [4.09065763],
#        [4.11089447],
#        [4.10712947],
#        [4.09677574],
#        [4.093952  ],
#        [4.10901197],
#        [4.08359827],
#        [4.06386971],
#        [4.10148199],
#        [4.06386971],
#        [4.06384148],
#        [4.09912887],
#        [4.11563836],
#        [4.11183571],
#        [4.08744798],
#        [4.10336448],
#        [4.11102624],
#        [4.11465946],
#        [4.08265702],
# ...

# %%
print(regressor.coef_)
# Out:
# [[-9.41248033e-06]]

# %%
print(regressor.intercept_)
# Out:
# [4.12029753]

# %%
sns.displot(y_pred-y_test, kind='kde')# to show the value of difference b/w actual value and prediction value

# %%
print(regressor.score(X_test, y_test))
# Out:
# -0.008715829080849335

# %%
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
